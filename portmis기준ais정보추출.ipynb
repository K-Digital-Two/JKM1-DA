# %%
import pandas as pd

# %%
ais = pd.read_csv('C:/Users/user/Desktop/항만운영정보시스템data/ModelingDataset/ais.csv',sep=',', encoding = 'cp949', index_col = 0) # ais정보로 바꾸기
portmis = pd.read_csv('C:/Users/user/Desktop/항만운영정보시스템data/ModelingDataset/portmis.csv',sep=',', encoding = 'cp949' ,index_col = 0)

# %%
portmis
# Out:
#      항명     호출부호         mmsi             선명  구분  외내  입출     총톤수  \
# 0    인천    3FDX9  371369000.0    POS BANGKOK  최종  외항  입항  18,085
# 1    인천     D7SK  441791000.0         코리아비너스  최종  내항  입항  29,543
# 2    인천    DSPF9  440918000.0        BONANZA  최종  외항  입항   3,690
# 3    인천    C6TM5  311697000.0   MORNING CALM  최종  외항  입항  57,692
# 4    인천     DSME  440432000.0           우림 7  최종  내항  입항   8,072
# ..   ..      ...          ...            ...  ..  ..  ..     ...
# 892  인천  V7A4986  538009640.0    KOBE TRADER  최종  외항  입항   9,944
# 893  인천    5LDT2  636021396.0  ZIM AUSTRALIA  최종  외항  입항  10,308
# 894  인천   130081  440061040.0            은성호  최종  내항  입항     321
# 895  인천     D7QA  440525000.0        거제 코델리아  최종  내항  입항   8,689
# 896  인천  9HA5618  229869000.0      PS AMALFI  최종  외항  입항  60,185
#
#                  입항일시              출항일시       전출항지      선박용도
# 0    2022-11-30 00:36  2022-11-30 13:54    SHANTOU    풀컨테이너선
# 1    2022-11-30 08:55  2022-12-01 08:55         여수  석유제품 운반선
# ...

# %%
shipList = list(portmis['mmsi'])
shipList
# Out:
# [371369000.0,
#  441791000.0,
#  440918000.0,
#  311697000.0,
#  440432000.0,
#  538005313.0,
#  538009208.0,
#  538005898.0,
#  477311800.0,
#  667001943.0,
#  563139700.0,
#  477585400.0,
#  235086166.0,
#  440121610.0,
#  440655000.0,
#  441953000.0,
#  538008860.0,
#  440011240.0,
#  440753304.0,
#  413073000.0,
#  538003355.0,
#  352001353.0,
#  667002134.0,
#  538008859.0,
#  440058060.0,
#  538003439.0,
#  564215900.0,
#  636018529.0,
#  533180215.0,
#  538007503.0,
#  630001010.0,
#  412500614.0,
#  414727000.0,
#  440017150.0,
#  440010160.0,
#  440328160.0,
#  440509320.0,
#  441287000.0,
#  181823.0,
#  354138000.0,
#  440021230.0,
#  440000910.0,
#  370403000.0,
#  441289000.0,
#  440218340.0,
#  477548100.0,
#  440058710.0,
#  636021614.0,
#  440419000.0,
#  312807000.0,
#  440120300.0,
#  312291000.0,
#  636021595.0,
#  440022920.0,
#  440555000.0,
#  312045000.0,
#  440148840.0,
#  440026590.0,
#  432809000.0,
#  352001622.0,
#  374990000.0,
#  441103000.0,
# ...

# %%
shiplog = ais[ais['mmsi'].isin(shipList)]
shiplog
# Out:
#                   insertTime       mmsi  speed    shipLat     shipLon
# 11       2022-11-30 16:33:05  371369000   17.1  37.264305  126.245270
# 12       2022-11-30 16:33:05  440022920    0.0  37.452236  126.610077
# 23       2022-11-30 16:33:05  235086166    9.7  37.004253  126.162865
# 34       2022-11-30 16:33:05  440022920    0.0  37.452225  126.610085
# 39       2022-11-30 16:33:05  441103000    5.3  37.327690  126.510292
# ...                      ...        ...    ...        ...         ...
# 2298236  2022-12-30 00:50:04  538010048    2.8  37.339527  126.634224
# 2298238  2022-12-30 00:50:05  441174000   11.7  37.188816  126.381104
# 2298246  2022-12-30 00:50:06  538007487   14.6  37.330166  126.456902
# 2298249  2022-12-30 00:50:07  538010048    2.8  37.339565  126.415787
# 2298253  2022-12-30 00:50:08  440017180    0.0  37.482044  126.398361
#
# [311146 rows x 5 columns]

# %%
shiplog.reset_index(drop=True, inplace = True)

# %%
shiplog
# Out:
#                  insertTime       mmsi  speed    shipLat     shipLon
# 0       2022-11-30 16:33:05  371369000   17.1  37.264305  126.245270
# 1       2022-11-30 16:33:05  440022920    0.0  37.452236  126.610077
# 2       2022-11-30 16:33:05  235086166    9.7  37.004253  126.162865
# 3       2022-11-30 16:33:05  440022920    0.0  37.452225  126.610085
# 4       2022-11-30 16:33:05  441103000    5.3  37.327690  126.510292
# ...                     ...        ...    ...        ...         ...
# 311141  2022-12-30 00:50:04  538010048    2.8  37.339527  126.634224
# 311142  2022-12-30 00:50:05  441174000   11.7  37.188816  126.381104
# 311143  2022-12-30 00:50:06  538007487   14.6  37.330166  126.456902
# 311144  2022-12-30 00:50:07  538010048    2.8  37.339565  126.415787
# 311145  2022-12-30 00:50:08  440017180    0.0  37.482044  126.398361
#
# [311146 rows x 5 columns]

# %%
shiplog.to_csv('C:/Users/user/Desktop/항만운영정보시스템data/ModelingDataset/shiplog.csv')

# %%
df = pd.read_csv('C:/Users/user/Desktop/항만운영정보시스템data/ModelingDataset/shiplog.csv', index_col = 0)

# %%
df
# Out:
#                  insertTime       mmsi  speed    shipLat     shipLon
# 0       2022-11-30 16:33:05  371369000   17.1  37.264305  126.245270
# 1       2022-11-30 16:33:05  440022920    0.0  37.452236  126.610077
# 2       2022-11-30 16:33:05  235086166    9.7  37.004253  126.162865
# 3       2022-11-30 16:33:05  440022920    0.0  37.452225  126.610085
# 4       2022-11-30 16:33:05  441103000    5.3  37.327690  126.510292
# ...                     ...        ...    ...        ...         ...
# 311141  2022-12-30 00:50:04  538010048    2.8  37.339527  126.634224
# 311142  2022-12-30 00:50:05  441174000   11.7  37.188816  126.381104
# 311143  2022-12-30 00:50:06  538007487   14.6  37.330166  126.456902
# 311144  2022-12-30 00:50:07  538010048    2.8  37.339565  126.415787
# 311145  2022-12-30 00:50:08  440017180    0.0  37.482044  126.398361
#
# [311146 rows x 5 columns]
